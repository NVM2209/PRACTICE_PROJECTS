# %% [markdown]
# # WORLD HAPPINESS REPORT (WHR) | PHASE-2 | PROJECT-2
# FlipRoboTechnology | Batch - DS2301 | Submitted By :- Neha Vibhor Mittal

# %% [markdown]
# ### DATASET INFORMATION-
# --This dataset is available on : https://github.com/dsrscientist/DSData/blob/master/happiness_score_dataset.csv
#
# Happiness is an emotional state characterized by feelings of joy, satisfaction, contentment, and fulfillment. While happiness has many different definitions, it is often described as involving positive emotions and life satisfaction.
#
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions.
# Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.
#
# - This Dataset includes over 158 records and 12 attributes.

# %% [markdown]
# #### PROBLEM IDENTIFICATION -
#
# What is Dystopia?
#
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width.
# - The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.
#
# - The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country.

# %% [markdown]
# #### Aim-To predict the happiness score considering all the other factors mentioned in the dataset.

# %% [markdown]
# #### Target :
# - Happiness Score
#    (We can observe that 'Happiness Score' has continuous data .This dataset can be viewed as Regression task.)

# %% [markdown]
# #### Labels :
#
# - Country : Name of the country.
# - Region : Region the country belongs to.
# - Happiness Rank : Rank of the country based on the Happiness Score.
# - Standard Error : The standard error of the happiness score.
# - Economy (GDP per Capita) : A a financial metric that breaks down a country's economic output per person.
# - Family : Family contributes to Happiness Score.
# - Health (Life Expectancy) : The expected number of remaining years of life spent in good health from a particular age.
# - Freedom : The power or right to act, speak, or think as one wants.
# - Trust (Government Corruption) : Trust on Government.
# - Generosity : The quality of being kind and generous.
# - Dystopia Residual : The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country.

# %% [markdown]
# #### IMPORTING NECESSARY LIBRARIES-

# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# #### LOAD THE DATASET -

# %%
whr = pd.read_csv('C:/Users/nehas/NehaProject/World_Happiness_Report/worldhappiness_score.csv')
whr.head()   # head()method will show the top 5 rows and columns
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# #### The following columns:
#
# - 1) GDP per Capita
# - 2) Family
# - 3) Life Expectancy
# - 4) Freedom
# - 5) Generosity
# - 6) Trust (Government Corruption)
#
#    describe the extent to which these factors contribute in evaluating the happiness in each country.
#
#
# - The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country.
#
#
#
# - The lowest scores observed for these six key variables, are characterize by 'Dystopia'. Since life would be very unpleasant in a country with the world’s lowest incomes(GDP per Capita), lowest life expectancy(Life Expectancy), lowest generosity(Generosity), most corruption(Trust (Government Corruption)), least freedom(Freedom) and least social support, it is referred to as “Dystopia,” in contrast to Utopia.
#
# What are the Residuals?
#
#    - The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average life evaluations. These residuals have an average value of approximately zero over the whole set of countries.

# %% [markdown]
# #### DATA EXPLORATION-

# %%
whr.shape   # to check the shape of the dataset
# Out:
# (158, 12)

# %%
whr
print("There are {:,} rows ".format(whr.shape[0]) + "and {} columns in our data".format(whr.shape[1]))
# Out:
# There are 158 rows and 12 columns in our data

# %% [markdown]
# - This Dataset has 158 instances and 12 attributes.Out of which , one is the Target variable and remaining 11 are independent variables.

# %%
whr.columns.tolist()    #to see the columns names in a list
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %% [markdown]
# - These are the names of the 12 columns present in a dataset.

# %%
whr.Region.unique()  #to find unique elements in columns
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
whr.Country.unique()
# Out:
# array(['Switzerland', 'Iceland', 'Denmark', 'Norway', 'Canada', 'Finland',
#        'Netherlands', 'Sweden', 'New Zealand', 'Australia', 'Israel',
#        'Costa Rica', 'Austria', 'Mexico', 'United States', 'Brazil',
#        'Luxembourg', 'Ireland', 'Belgium', 'United Arab Emirates',
#        'United Kingdom', 'Oman', 'Venezuela', 'Singapore', 'Panama',
#        'Germany', 'Chile', 'Qatar', 'France', 'Argentina',
#        'Czech Republic', 'Uruguay', 'Colombia', 'Thailand',
#        'Saudi Arabia', 'Spain', 'Malta', 'Taiwan', 'Kuwait', 'Suriname',
#        'Trinidad and Tobago', 'El Salvador', 'Guatemala', 'Uzbekistan',
#        'Slovakia', 'Japan', 'South Korea', 'Ecuador', 'Bahrain', 'Italy',
#        'Bolivia', 'Moldova', 'Paraguay', 'Kazakhstan', 'Slovenia',
#        'Lithuania', 'Nicaragua', 'Peru', 'Belarus', 'Poland', 'Malaysia',
#        'Croatia', 'Libya', 'Russia', 'Jamaica', 'North Cyprus', 'Cyprus',
# ...

# %%
whr.nunique()    #nunique() method returns the number of unique values for each column
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
#checking the value count for each columns

for key,value in whr.items():   
    print('-' * 50 + key + '-' * 70 , end=' - ')
    print(whr[key].value_counts(),"\n")
# Out:
# --------------------------------------------------Country---------------------------------------------------------------------- - Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
# --------------------------------------------------Region---------------------------------------------------------------------- - Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
# ...

# %%
print("Min happiness score :",whr['Happiness Score'].min())
print("Max happiness score :",whr['Happiness Score'].max())
# Out:
# Min happiness score : 2.839
# Max happiness score : 7.587

# %%
whr.style.highlight_max(subset = ['Region', 'Happiness Score'],
                       color = 'lightgreen', axis = 0)
# Out:
# <style type="text/css">
# #T_15828_row0_col1, #T_15828_row0_col3, #T_15828_row1_col1, #T_15828_row2_col1, #T_15828_row3_col1, #T_15828_row5_col1, #T_15828_row6_col1, #T_15828_row7_col1, #T_15828_row12_col1, #T_15828_row16_col1, #T_15828_row17_col1, #T_15828_row18_col1, #T_15828_row20_col1, #T_15828_row25_col1, #T_15828_row28_col1, #T_15828_row35_col1, #T_15828_row36_col1, #T_15828_row49_col1, #T_15828_row65_col1, #T_15828_row66_col1, #T_15828_row87_col1, #T_15828_row101_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_15828">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15828_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_15828_level0_col1" class="col_heading level0 col1" >Region</th>
#       <th id="T_15828_level0_col2" class="col_heading level0 col2" >Happiness Rank</th>
#       <th id="T_15828_level0_col3" class="col_heading level0 col3" >Happiness Score</th>
# ...

# %% [markdown]
# - The green highlights indicate the region with the lowest Happiness score.

# %%
whr.describe()  # to check the Statistical summary
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# #### Key Observations:-
#    - All the columns has same count as 158 which means there is no null values in the dataset.
#     - Data is symmetrically or normally distributed, as mean and median close to each other.
#      - There is some difference between the 75% (Q3 quantile ) and max values in 'Happiness rank','Happiness score' ,'Standard error',Health'and 'Dystopia residual',which indicates there is skewness in the data.
#     - Except 'Happiness rank' and 'Happiness Score',each column has standard deviation close to zero.

# %%
whr.info()   # to check the information present in a datset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# #### Key Observations-
# - There are total 158 entries(rows) with 12 columns with integer64,object and float64 datatypes of variables.
# - In the above dataset, the target is to predict the 'Happiness Score'. We can observe that 'Happiness Score' has continuous data and float as data type where as 'Happiness rank'is int64 .so we need to convert it into float datatype
# - The second column give us an idea about how big the dataset and how many non-null values are there for each field.
# - The total memory usage is 14.9+kb.

# %%
#Converting into Float Data Type
whr['Happiness Rank']= whr['Happiness Rank'].astype(float)

# %%
whr.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                   float64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# - As seen above , the datatype of 'Happiness Rank 'is now converted into float64.

# %%
whr.isnull().sum()   #Checking for NULL values if any in the data frame
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# - There is no null values in this dataset.

# %% [markdown]
# ### DATA VISUALIZATION

# %%
#Checking for null values using heatmap.

plt.figure(figsize=(10,5))

sns.heatmap(whr.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# - No significant Null values seen using heatmap.

# %% [markdown]
# ##### Grouping two variables together to check the relation among them.

# %%
#Using groupby for grouping the data.

whr.groupby('Country')['Happiness Score'].max().sort_values(ascending=True).head(20).plot(kind='bar', figsize=(12,6),color='red')
plt.title('Least Happiest Countries')
plt.show()

# %% [markdown]
# - As seen by above mentioned graph,'TOGO'is the least happiest country among others,followed by 'BURUNDI'and 'SYRIA'.

# %%
whr.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).head(20).plot(kind='bar', figsize=(12,6),color='gold')
plt.title('Top 20 happiest countries')
plt.show()

# %% [markdown]
# - As seen from above mentioned graph,'SWIZERLAND'is the TOP happiest country among others,followed by 'ICELAND'and 'DENMARK'.

# %%
#Visualising data using Countplot


print('Regions Counts:\n')

plt.figure(figsize=(10,10))
sns.countplot(whr['Region'])
plt.xticks(rotation=90)
plt.title('Regions')
# Out:
# Regions Counts:
# Text(0.5, 1.0, 'Regions')

# %% [markdown]
# - Regions like 'Sub-Saharan African'(40) , 'Central and Eastern Europe'(29) and 'Latin America and Caribbean'(22) has the highest number of counts in those regions

# %% [markdown]
# #### FACTORS THAT DETERMINES HAPPINESS-

# %%
# Determine the mean for the happiness factors

factors = ['Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity']
factors_mean = whr.groupby('Region')[factors].mean()
factors_mean
# Out:
#                                  Economy (GDP per Capita)    Family  \
# Region
# Australia and New Zealand                        1.291880  1.314450
# Central and Eastern Europe                       0.942438  1.053042
# Eastern Asia                                     1.151780  1.099427
# Latin America and Caribbean                      0.876815  1.104720
# Middle East and Northern Africa                  1.066974  0.920490
# North America                                    1.360400  1.284860
# Southeastern Asia                                0.789054  0.940468
# Southern Asia                                    0.560486  0.645321
# Sub-Saharan Africa                               0.380473  0.809085
# Western Europe                                   1.298596  1.247302
#
#                                  Health (Life Expectancy)   Freedom  \
# Region
# Australia and New Zealand                        0.919965  0.645310
# ...

# %%
multi_plot = factors_mean.plot(kind='barh', figsize=(10,10), title = "Factors Mean by Region")
plt.legend(bbox_to_anchor=(1,0.9), loc="upper right")

plt.show()

# %% [markdown]
# - Graphical representation of the various Factors that determines happiness which in majority of cases in every specific regions was found to be 'Economy(GDP)' and 'Family'while the least was 'Trust(Government Corruption).

# %%
region_mean = whr.groupby('Region')['Happiness Score'].mean().sort_values(ascending=False)

fig, ax = plt.subplots(1, 1, figsize=(15, 6))
plot = sns.barplot(x=region_mean.index, y=region_mean, ax=ax,edgecolor='.2')
i = 0
for index, row in region_mean.iteritems():
    plot.text(x = i, y = row*1.01, s=round(row, 2), 
            ha='center')                      #horizonal alignment(ha)
    i += 1

plt.title('Region and Happiness Score (Mean)', fontdict={'fontweight':'bold'})
plt.xlabel('Region', fontweight='bold')
plt.ylabel('Happiness Score', fontweight='bold')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - Region-wise happiness score level was found to be maximum in Australia and New Zealand while the least in SubSaharan Africa.

# %%
data = whr.groupby('Country').mean().T

data
# Out:
# Country                        Afghanistan   Albania   Algeria     Angola  \
# Happiness Rank                   153.00000  95.00000  68.00000  137.00000
# Happiness Score                    3.57500   4.95900   5.60500    4.03300
# Standard Error                     0.03084   0.05013   0.05099    0.04758
# Economy (GDP per Capita)           0.31982   0.87867   0.93929    0.75778
# Family                             0.30285   0.80434   1.07772    0.86040
# Health (Life Expectancy)           0.30335   0.81325   0.61766    0.16683
# Freedom                            0.23414   0.35733   0.28579    0.10384
# Trust (Government Corruption)      0.09719   0.06413   0.17383    0.07122
# Generosity                         0.36510   0.14272   0.07822    0.12344
# Dystopia Residual                  1.95210   1.89894   2.43209    1.94939
#
# Country                        Argentina    Armenia  Australia   Austria  \
# Happiness Rank                  30.00000  127.00000   10.00000  13.00000
# ...

# %% [markdown]
# ##### Using Various other methods to visualize the graphs with the mean value and check the relationship between them.

# %%
# Groupby and determine the mean for 'Region' and Target Variable ' Happiness Score'.

region_happiness = whr.groupby('Region')['Happiness Score'].mean().sort_values(ascending=False)
region_happiness
# Out:
# Region
# Australia and New Zealand          7.285000
# North America                      7.273000
# Western Europe                     6.689619
# Latin America and Caribbean        6.144682
# Eastern Asia                       5.626167
# Middle East and Northern Africa    5.406900
# Central and Eastern Europe         5.332931
# Southeastern Asia                  5.317444
# Southern Asia                      4.580857
# Sub-Saharan Africa                 4.202800
# Name: Happiness Score, dtype: float64

# %%
happreg = region_happiness.plot(kind='bar' ,edgecolor='.2')
plt.xlabel("Region")
plt.ylabel("Happiness Score")
# Out:
# Text(0, 0.5, 'Happiness Score')

# %%
sns.countplot(data=whr, y='Region', hue='Happiness Score')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Region'>

# %%
# Grouby and determine the mean for 'Region' and 'Economy'
region_economy_GDP = whr.groupby('Region')['Economy (GDP per Capita)'].mean()
region_economy_GDP
# Out:
# Region
# Australia and New Zealand          1.291880
# Central and Eastern Europe         0.942438
# Eastern Asia                       1.151780
# Latin America and Caribbean        0.876815
# Middle East and Northern Africa    1.066974
# North America                      1.360400
# Southeastern Asia                  0.789054
# Southern Asia                      0.560486
# Sub-Saharan Africa                 0.380473
# Western Europe                     1.298596
# Name: Economy (GDP per Capita), dtype: float64

# %%
#Visualising the above data -

plt.figure(figsize=(10,6))
ax = region_economy_GDP.plot.bar(rot=0, edgecolor='.2', color={ "red"})
plt.xticks(rotation=90)
plt.title('Regions EconomyGDP ')
# Out:
# Text(0.5, 1.0, 'Regions EconomyGDP ')

# %%
# Create a pie chart based on the  region and economy groupby data-

plt.figure(figsize = (15,10))
create_chart_GDP = region_economy_GDP.plot(kind='pie',figsize=(15,10),autopct = '%.1f%%')
plt.title('REGION ECONOMY(GDP)')

# %% [markdown]
# - Based on the above graph representation,14.0%  economy level was found to be in Northern America and the least in 'Sub-Saharan Africa' i.e 3.9%.

# %%
happeco= whr.plot(kind = "scatter", x = "Economy (GDP per Capita)", y = "Happiness Score")

# %% [markdown]
# - With increase in economy levels ,there is increase in 'Happiness Score'.This show positive relationship between them.This determines that Economy is one of the main reasons for increase in happiness level.

# %%
sns.regplot(data= whr,x='Happiness Score',y='Health (Life Expectancy)',color="g")
plt.show()

# %% [markdown]
# - With increase in Health and life expectancy levels ,there is increase in 'Happiness Score'.This show positive relationship between them.This determines that Health is also one of the main reasons for increase in happiness level.

# %%
# Grouby and determine the mean for Region and Family
region_happiness_Fam = whr.groupby('Region')['Family'].mean()


# Create a barh chart based off of the region and family groupby 
plt.figure(figsize=(10,6))
Fam = region_happiness_Fam.plot(kind='barh',color='green',edgecolor='.2')

# Set the xlabel and ylabel using class methods
Fam.set_xlabel("Family")
Fam.set_ylabel("Region")
# Out:
# Text(0, 0.5, 'Region')

# %%
# Grouby and determine the mean for Region and Health
happiness_health = whr.groupby('Region')['Health (Life Expectancy)'].mean()

# Create a bar chart based off of the region and health groupby 
plt.figure(figsize=(10,6))
health = happiness_health.plot(kind='barh')

# Set the xlabel and ylabel using class methods
health.set_xlabel("Region")
health.set_ylabel("Health (Life Expectancy)")
# Out:
# Text(0, 0.5, 'Health (Life Expectancy)')

# %% [markdown]
# - 'Australia and New Zealand','North America','Central europe'and 'Western Europe'were some regions were the health(life expectany )was seen highest while the least in ' Sub-Saharan Africa'.

# %%
# Grouby and determine the mean for Region and Trust
trust = whr.groupby('Region')['Trust (Government Corruption)'].mean()

# Create a bar chart based off of the region and trust groupby 
plt.figure(figsize=(10,6))
whrtrust = trust.plot(kind='barh',color='yellow',edgecolor='.2')

# Set the xlabel and ylabel using class methods
whrtrust.set_xlabel("Region")
whrtrust.set_ylabel("Trust (Government Corruption)")
# Out:
# Text(0, 0.5, 'Trust (Government Corruption)')

# %%
sns.regplot(data= whr,x='Happiness Score',y='Generosity',color="r")
plt.show()

# %%
sns.regplot(data= whr,x='Happiness Score',y='Dystopia Residual',color="r")
plt.show()

# %%
sns.regplot(data= whr,x='Happiness Score',y='Family',color="g")
plt.show()

# %% [markdown]
# - Family contributes to Happiness Score.there is increase in 'Happiness Score'.This show positive relationship between them.This determines that family is one of the main reasons for increase in happiness level.

# %%
#Calculating the pairplot for the dataset

sns.pairplot(whr, hue='Region', palette='husl')

# %% [markdown]
# - Pairplot shows pairwise distribution

# %% [markdown]
# #### DISTRIBUTION PLOT

# %%
#Distribution of Continuous data:only taking the continuous features:

data_features = whr[['Happiness Score','Happiness Rank',
       'Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual']]

# %%
# Making Distribution plot of above data-

plt.figure(figsize=(15,10),facecolor ='red')
x = 1 

for i in data_features:
    if x <= 10:
        ax=plt.subplot(2,5,x)
        sns.histplot(data_features[i], kde=True, bins=20)
        plt.xlabel(i, fontsize = 15)
    x += 1
    
plt.show()

# %% [markdown]
# #### Key Observation-
# - From above Histograms, it can be seen that 'Dystopia Residual' is normally Distributed.
# - Data distribution of 'Happiness score' is normally distributed.
# - 'Standard Error' data is positively skewed.
# - 'Economy(GDP per capia)'  data looks normally distributed.
# - 'Family' and ,'Freedom' data is negatively skewed.
# -  'Health (Life Expectancy)' data is negatively skewed.
# - 'Trust(Government corruption)' and 'Generosity' is positively skewed.

# %% [markdown]
# #### Handling Skewness

# %%
data_features.skew()   # checking for skewness
# Out:
# Happiness Score                  0.097769
# Happiness Rank                   0.000418
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# #### Key Observations-
# -  The columns which does not lie within the range of skewness,( +/-0.5) are:-
#     - Standard Error
#     - Family
#     - Health (Life Expectancy)
#     - Trust (Government Corruption)
#     - Generosity

# %% [markdown]
# #### CHECKING AND REMOVING OUTLIERS AND SKEWNESS

# %%
# Detecting outliers using boxplot.

plt.figure(figsize=(15,10),facecolor='gold')
num = 1

for col in data_features:
    if num <= 10:
        data = plt.subplot(2,5,num)
        sns.boxplot(data_features[col])
        plt.xlabel(col,fontsize=15)
    num +=1
    
plt.show()

# %% [markdown]
# #### key observations:
#     - Total 10 columns are present.
#     - As we can see ,there are 5 features with outliers present .They are 'Standard Error','Family','Trust(Government Corruption)','Generosity','Dystopia Residual' which have outliers in both ends.
#     - 'Happiness Score','Happiness Rank','EconomyGDP','Health' and 'Freedom' features has no outliers.

# %%
from sklearn.preprocessing import PowerTransformer

# %%
skew = PowerTransformer(method = 'yeo-johnson')

# %%
data_features[['Standard Error','Family','Trust (Government Corruption)','Generosity','Dystopia Residual']] = skew.fit_transform(data_features[['Standard Error','Family','Trust (Government Corruption)','Generosity','Dystopia Residual']])

# %%
# Rechecking outliers using boxplot.

plt.figure(figsize=(15,10),facecolor='green')
num = 1

for col in data_features:
    if num <= 10:
        data = plt.subplot(2,5,num)
        sns.boxplot(data_features[col])
        plt.xlabel(col,fontsize=15)
    num +=1
    
plt.show()

# %%
plt.figure(figsize=(15,10))
x = 1 

for i in data_features:
    if x <= 10:
        ax=plt.subplot(2,5,x)
        sns.histplot(data_features[i], kde=True, bins=20)
        plt.xlabel(i, fontsize = 15)
    x += 1
    
plt.show()

# %%
data_features.skew()
# Out:
# Happiness Score                  0.097769
# Happiness Rank                   0.000418
# Standard Error                  -0.020092
# Economy (GDP per Capita)        -0.317575
# Family                          -0.169651
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.185965
# Generosity                       0.013320
# Dystopia Residual                0.022925
# dtype: float64

# %% [markdown]
# - From sklearn preprocessing using PowerTransform with method is Yeo-Johnson to remove skewness and outliers.This will work on negative as well as positive outliers on dataset.

# %%
# dropping categorical columns 'Country' and 'Region' as they are nominal and the target variable -

x = whr.drop(columns = ['Country','Region','Happiness Score'],axis = 1)
x
# Out:
#      Happiness Rank  Standard Error  Economy (GDP per Capita)   Family  \
# 0               1.0         0.03411                   1.39651  1.34951
# 1               2.0         0.04884                   1.30232  1.40223
# 2               3.0         0.03328                   1.32548  1.36058
# 3               4.0         0.03880                   1.45900  1.33095
# 4               5.0         0.03553                   1.32629  1.32261
# ..              ...             ...                       ...      ...
# 153           154.0         0.03464                   0.22208  0.77370
# 154           155.0         0.03656                   0.28665  0.35386
# 155           156.0         0.05015                   0.66320  0.47489
# 156           157.0         0.08658                   0.01530  0.41587
# 157           158.0         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
# Label/Target variable 

y= whr['Happiness Score']
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %% [markdown]
# #### Visualizing the Relation Between Features with Label: We are using Regression Plot for Visualization.

# %%
plt.figure(figsize=(20,15),facecolor='white')
plot = 1

for column in x:
    if plot<= 9:
        xx=plt.subplot(3,3,plot)
        sns.regplot(x[column],y)
        plt.xlabel(column,fontsize=15)
        plt.ylabel('Happiness Score',fontsize=15)
        
    plot +=1
    
plt.show()

# %% [markdown]
# #### CORRELATION MATRIX

# %% [markdown]
# #### Finding the coefficient of multicolinearity to check if any features is corelated to eachother or not.

# %%
Happinesscor= whr.corr().abs() # to check the correlation of the dataset.
Happinesscor
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000         0.992105
# Happiness Score                      0.992105         1.000000
# Standard Error                       0.158516         0.177254
# Economy (GDP per Capita)             0.785267         0.780966
# Family                               0.733644         0.740605
# Health (Life Expectancy)             0.735613         0.724200
# Freedom                              0.556886         0.568211
# Trust (Government Corruption)        0.372315         0.395199
# Generosity                           0.160142         0.180319
# Dystopia Residual                    0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                  0.785267
# Happiness Score                      0.177254                  0.780966
# ...

# %%
#constructing a heatmap to understand the correlation between the columns 

plt.figure(figsize=(15,10))  
sns.heatmap(Happinesscor.cor, cbar=True, linewidth=0.3, annot=True, fmt='.2f', cmap='viridis')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Key Observations--
# - 'Happiness Rank' is strongly correlated with 'Happiness Score'.
# - 'Happiness Score' has good correlation with economy, Health, Family and Freedom
# - 'Happiness Score' has moderate correlation with 'Dystopia Residual'and 'Trust( Government corruption).
# - 'Happiness Score' has poor correlation wit Generosity
#
# So we can say that Economy, Health, Family and freedom plays am important role in the happiness of the country where as 'Trust( Government corruption), Generosity will not hav any effect in the happiness score of the country.

# %% [markdown]
# #### SCALING THE DATA(STANDARD SCALER)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_scaled = scaler.fit_transform(x)
x
# Out:
#      Happiness Rank  Standard Error  Economy (GDP per Capita)   Family  \
# 0               1.0         0.03411                   1.39651  1.34951
# 1               2.0         0.04884                   1.30232  1.40223
# 2               3.0         0.03328                   1.32548  1.36058
# 3               4.0         0.03880                   1.45900  1.33095
# 4               5.0         0.03553                   1.32629  1.32261
# ..              ...             ...                       ...      ...
# 153           154.0         0.03464                   0.22208  0.77370
# 154           155.0         0.03656                   0.28665  0.35386
# 155           156.0         0.05015                   0.66320  0.47489
# 156           157.0         0.08658                   0.01530  0.41587
# 157           158.0         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# - Using Standard Scaler to scale the value of dataset, So that our Model will not be bias and treat every single column equally

# %% [markdown]
# #### VARIANCE INFLATION FACTOR-

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['vif'] = [variance_inflation_factor(x_scaled,i)for i in range(x_scaled.shape[1])]
vif["Features"] = x.columns
vif
# Out:
#          vif                       Features
# 0  71.573977                 Happiness Rank
# 1   1.177539                 Standard Error
# 2  12.578340       Economy (GDP per Capita)
# 3   5.539781                         Family
# 4   7.951242       Health (Life Expectancy)
# 5   3.079817                        Freedom
# 6   1.948717  Trust (Government Corruption)
# 7   1.898209                     Generosity
# 8  16.988518              Dystopia Residual

# %% [markdown]
# #### MODEL BUILDING-

# %%
#for Training-testing data
from sklearn.model_selection import train_test_split

# Models:
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge,Lasso
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor


# for cross validation
from sklearn.model_selection import cross_val_score,GridSearchCV

# Matrics for Evaluation
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %% [markdown]
# ##### Finding the best random state

# %%
lr =  LinearRegression()

# %%
#split data, using train_test_split

for i in range(0,100):
    X_train,X_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.2,random_state=i)
    lr.fit(X_train,y_train)
    pred_train = lr.predict(X_train)
    pred_test = lr.predict(X_test)
    
    
    print(f"At random state {i},the training accuracy is :- {r2_score(y_train,pred_train)}")
    print(f"At random state {i},the test accuracy is :- {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is :- 0.9999999493262122
# At random state 0,the test accuracy is :- 0.9999999030202089
#
#
# At random state 1,the training accuracy is :- 0.9999999430295653
# At random state 1,the test accuracy is :- 0.9999999332198619
#
#
# At random state 2,the training accuracy is :- 0.9999999372718591
# At random state 2,the test accuracy is :- 0.9999999542684379
#
#
# At random state 3,the training accuracy is :- 0.9999999413308461
# At random state 3,the test accuracy is :- 0.9999999418817217
#
#
# At random state 4,the training accuracy is :- 0.999999935510487
# At random state 4,the test accuracy is :- 0.9999999490151793
#
#
# At random state 5,the training accuracy is :- 0.9999999467561439
# At random state 5,the test accuracy is :- 0.9999999030820294
#
#
# At random state 6,the training accuracy is :- 0.9999999441107331
# At random state 6,the test accuracy is :- 0.9999999319401313
#
#
# ...

# %% [markdown]
# ### 1) LINEAR REGRESSION
# - Model Training:Taking the random state where difference between training and testing accuracy is minimum. Taking random state = 41

# %%
X_train,X_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.25,random_state=41)
lr.fit(X_train,y_train)
lr.score(X_train,y_train)
# Out:
# 0.999999940647654

# %%
#Model Prediction with trained data:

pred_train=lr.predict(X_train)
print(r2_score(y_train,pred_train))

pred_test=lr.predict(X_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.999999940647654
# 0.9999999420213352

# %%
cv_linearreg = cross_val_score(estimator = lr, X = x, y = y, cv = 5)
cv_linearreg
# Out:
# array([0.99999947, 0.99999839, 0.99999831, 0.99999539, 0.99999945])

# %%
# Checking Actual Vs Predicted using Graph:

plt.figure(figsize=(8,6))
plt.scatter(y_train,pred_train,color ='r')
plt.plot(y_test,y_test,color ='b')

plt.xlabel('Happiness Score')
plt.ylabel('Predicted Happiness Score')
plt.title('Actual Happiness Score Vs Predicted Happiness Score of Linear Regression')
plt.show()

# %%
print ('mean absolute error of linear regression is(mae): ',mean_absolute_error(y_test,pred_test))
print ('mean squared error of linear regression is (mse): ',mean_squared_error(y_test,pred_test))
print ('Root mean squared error of linear regression is(rmse): ',np.sqrt(mean_squared_error(y_test,pred_test)))
print('Accuracy of Linear Regression Model : ',r2_score(y_test,pred_test)*100)
# Out:
# mean absolute error of linear regression is(mae):  0.000239262622182701
# mean squared error of linear regression is (mse):  7.948614032635766e-08
# Root mean squared error of linear regression is(rmse):  0.00028193286492773
# Accuracy of Linear Regression Model :  99.99999420213352

# %% [markdown]
# ### 2) Regularization using Lasso and Ridge -

# %% [markdown]
# #### LASSO REGULARIZATION

# %%
ls = Lasso()
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],
    'random_state':list(range(0,10))}

las=GridSearchCV(ls,parameters)
las.fit(X_train,y_train)
print(las.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
#final model training and testing

ls=Lasso(alpha=0.001,random_state=0)
ls.fit(X_train,y_train)
ls_score = ls.score(X_train,y_train)
print("Lasso Score:",ls.score(X_train,y_train)*100)
# Out:
# Lasso Score: 99.99765405132824

# %%
cv_lsscore = cross_val_score(ls,x_scaled,y,cv = 5)
cv_mean = cv_lsscore.mean()*100
print("CV SCORE  :",cv_mean)

predlasso=ls.predict(X_test)
print('mean squared error of lasso is (mse): ',mean_squared_error(y_test,predlasso))
print ('mean absolute error of lasso is(mae): ',mean_absolute_error(y_test,predlasso))
print('RMSE:',np.sqrt(mean_squared_error(y_test,predlasso)))
print('Accuracy of Lasso : ',r2_score(y_test,predlasso)*100)
# Out:
# CV SCORE  : 99.81816224089813
# mean squared error of lasso is (mse):  2.5690389078896366e-05
# mean absolute error of lasso is(mae):  0.0037785996057125293
# RMSE: 0.005068568740669931
# Accuracy of Lasso :  99.99812609538031

# %% [markdown]
# #### Ridge Regularization

# %%
#Training Data

rd = Ridge(alpha = .0001)
rd.fit(X_train,y_train)
print(rd.score(X_train,y_train))
# Out:
# 0.9999999406348669

# %%
# Testing Data

predridge= rd.predict(X_test)
print('Mean squared error of ridge (mse):',mean_squared_error(y_test,predridge))
print ('mean absolute error of ridge is(mae): ',mean_absolute_error(y_test,predridge))
print('RMSE:',np.sqrt(mean_squared_error(y_test,predridge)))
print('Accuracy of Ridge : ',r2_score(y_test,predridge)*100)


cv_rdscore = cross_val_score(rd,x_scaled,y,cv = 5)
cv_mean = cv_rdscore.mean()*100
print("CV SCORE  :",cv_mean)
# Out:
# Mean squared error of ridge (mse): 7.934233622626411e-08
# mean absolute error of ridge is(mae):  0.00023931521830660162
# RMSE: 0.00028167771695017716
# Accuracy of Ridge :  99.99999421262287
# CV SCORE  : 99.99982105539837

# %% [markdown]
# ### 3) RandomForest Regressor

# %%
rf = RandomForestRegressor()

parameters = {
    'criterion':['mse','mae'],
    'max_features':['auto','sqrt','log2']}

# %%
grid_rf = GridSearchCV(rf,parameters)
grid_rf.fit(X_train,y_train)
print(grid_rf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
#Training Data

rf = RandomForestRegressor(criterion = "mae" ,  max_features= "auto")
rf.fit(X_train,y_train)
rf.score(X_train,y_train)
# Out:
# 0.9993773963063863

# %%
# Testing Data

predrf= rf.predict(X_test)

print('Mean squared error of Random forest (mse):',mean_squared_error(y_test,predrf))
print ('mean absolute error of Random forest is(mae): ',mean_absolute_error(y_test,predrf))
print('RMSE :',np.sqrt(mean_squared_error(y_test,predrf)))
print('Accuracy of Random forest:',r2_score(y_test,predrf)*100)


cv_rfrscore = cross_val_score(rf,x_scaled,y,cv = 5)
cv_mean = cv_rfrscore.mean()*100
print("CV SCORE  :",cv_mean)
# Out:
# Mean squared error of Random forest (mse): 0.007741198544999951
# mean absolute error of Random forest is(mae):  0.04824550000000009
# RMSE : 0.0879840812022263
# Accuracy of Random forest: 99.43534262284321
# CV SCORE  : -160.05883352777434

# %% [markdown]
# #### 4) Support Vector Machine (Regression)   SVM

# %%
svr=SVR()

# %%
#Training Data

svr.fit(X_train,y_train)
svr.score(X_train,y_train)
# Out:
# 0.9898822101254273

# %%
# Testing Data

predsvr= svr.predict(X_test)

print('Mean squared error of SVR (mse):',mean_squared_error(y_test,predsvr))
print ('mean absolute error of SVR is(mae): ',mean_absolute_error(y_test,predsvr))
print('RMSE :',np.sqrt(mean_squared_error(y_test,predsvr)))
print('Accuracy of SVR:',r2_score(y_test,predsvr)*100)


cv_svrscore = cross_val_score(svr,x_scaled,y,cv = 5)
cv_mean = cv_svrscore.mean()*100
print("CV SCORE SVR :",cv_mean)
# Out:
# Mean squared error of SVR (mse): 0.13610292567081722
# mean absolute error of SVR is(mae):  0.2310887662332773
# RMSE : 0.3689213001045307
# Accuracy of SVR: 90.07240021220119
# CV SCORE SVR : -300.48091778761926

# %% [markdown]
# #### 5) Ada Boost Regressor

# %%
ada = AdaBoostRegressor()

params = {'n_estimators':[40,45,50,51,52,53,54],
    'learning_rate':[0.8,0.9,1.0,1.1,1.2],
    'loss':['linear', 'square', 'exponential'],}

# %%
ada_param=GridSearchCV(ada,param_grid=params,cv=5)

ada_param.fit(X_train,y_train)
print(ada_param.best_params_)
# Out:
# {'learning_rate': 1.2, 'loss': 'exponential', 'n_estimators': 53}

# %%
#Training Data
ada = ada_param.best_estimator_
ada.fit(X_train,y_train)
ada.score(X_train,y_train)
# Out:
# 0.9983332462643875

# %%
# Testing Data

predada= ada.predict(X_test)

print('Mean squared error of ADA (mse):',mean_squared_error(y_test,predada))
print ('mean absolute error of ADA is(mae): ',mean_absolute_error(y_test,predada))
print('RMSE :',np.sqrt(mean_squared_error(y_test,predada)))
print('Accuracy of ADA :',r2_score(y_test,predada)*100)


cv_adascore = cross_val_score(ada,x_scaled,y,cv = 5)
cv_mean = cv_adascore.mean()*100
print("CV SCORE ADA  :",cv_mean)
# Out:
# Mean squared error of ADA (mse): 0.008505983665163705
# mean absolute error of ADA is(mae):  0.059056147763628296
# RMSE : 0.09222788984447007
# Accuracy of ADA : 99.37955777796034
# CV SCORE ADA  : -263.5991243741895

# %% [markdown]
# ### With 99.9% accuracy, Linear Regression model is the best model for the given dataset.

# %% [markdown]
# #### Saving the model in the pickle format

# %%
import pickle

filename = 'WHR.pkl'

pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# #### Conclusion

# %%
model = pickle.load(open('WHR.pkl','rb'))

lr_pred = model.predict(X_test)

result = r2_score(y_test,pred_test)

print(result*100)
# Out:
# 99.99999420213352

# %%
conclusion = pd.DataFrame([lr_pred,y_test],index=['Predicted','Original'])
conclusion
# Out:
#                  0         1         2         3         4         5   \
# Predicted  4.550672  3.780861  5.588693  5.604695  3.896478  4.194297
# Original   4.550000  3.781000  5.589000  5.605000  3.896000  4.194000
#
#                  6         7         8         9   ...        30        31  \
# Predicted  6.797713  7.283948  4.512263  6.810225  ...  4.033122  6.867214
# Original   6.798000  7.284000  4.512000  6.810000  ...  4.033000  6.867000
#
#                  32        33        34        35        36       37  \
# Predicted  5.889083  5.754379  4.307004  7.526981  5.847613  5.10161
# Original   5.889000  5.754000  4.307000  7.527000  5.848000  5.10200
#
#                  38        39
# Predicted  5.688704  6.328937
# Original   5.689000  6.329000
#
# [2 rows x 40 columns]

# %% [markdown]
# #### With 99.9% accuracy, Linear Regression model is the best model for the given dataset.¶

# %% [markdown]
# ### ********COMPLETED*********
