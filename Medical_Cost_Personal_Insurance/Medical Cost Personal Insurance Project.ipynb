# %% [markdown]
# # MEDICAL COST PERSONAL INSURANCE | PHASE-1 | PROJECT-1
#
# FlipRoboTechnology  | Batch - DS2301 | Submitted By :- Neha Vibhor Mittal

# %% [markdown]
# #### DATASET INFORMATION -
#
# --This dataset is available on : https://github.com/dsrscientist/dataset4/blob/main/medical_cost_insurance.csv
#
# Health insurance is a type of insurance that covers all medical expenses that arise due to an illness. These expenses could be related to hospitalisation costs, cost of medicines or doctor consultation fees. The main purpose of medical insurance is to receive the best medical care without any strain on your finances. Health insurance plans offer protection against high medical costs. It covers hospitalization expenses, day care procedures, domiciliary expenses, and ambulance charges, besides many others.
#
# Based on certain input features such as age , bmi,Sex,no of dependents ,smoker ,region,  medical cost insurance is calculated .
# This dataset contains both numerical and categorical data.
#
# This Dataset includes over 1338 instances and  7 attributes.

# %% [markdown]
# #### Problem Identification-
# To study the accuracy and accurately predict insurance costs.

# %% [markdown]
# #### Attribute Information-
#
#  -	Age: age of primary beneficiary
#  -	Sex: insurance contractor gender, female, male
#  -	BMI: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height, objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9.
#  -	Children: Number of children covered by health insurance / Number of dependents
#  -	Smoker: Smoking
#  -	Region: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.
#  -	Charges: Individual medical costs billed by health insurance

# %% [markdown]
# #### VARIABLE-
# - Numerical  -4
# - Categorical - 3

# %% [markdown]
# #### TOOLS USED :-
# The following tools are going to be used for data analysis-
#
# - Pandas
# - Numpy
# - Matplotlib
# - Seaborn
# - Scikit-learn

# %% [markdown]
# #### IMPORTING NECESSARY LIBRARIES-

# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# #### LOAD THE DATASET -

# %%
data=pd.read_csv('medical_cost_insurance.csv')
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.head()   # head()method will show the top 5 rows and columns
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.tail()    #tail() Returns the last 5 rows and columns.
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %% [markdown]
# #### DATA EXPLORATION-

# %%
data.shape    # to check the shape of the dataset
# Out:
# (1338, 7)

# %% [markdown]
# - This shows that there are 1338 rows and 7 columns.

# %%
data.keys()
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
data.columns.tolist()  #to see the columns names
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %% [markdown]
# - These are the names of 7 attributes present in tha dataset.

# %%
data.info()  # to check the information present in a datset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# #### KEY INFORMATION FROM ABOVE DATASET-
# - There are total 1338 instances with 7 attributes with integer64(2),object(3) and float64(2) datatypes of variables.
# - The second column give us an idea about how big the dataset and how many non-null values are there for each field.
# - The total memory usage is 73.3+kb.

# %%
data.isna().sum()   #to check the null values  in the dataet
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# - There is no such null values present in this dataset and the datatype is int64 .

# %%
#checking the value count for each columns

for col in data.columns:   
    print('-' * 50 + col + '-' * 50 , end=' - ')
    display(data[col].value_counts().head(10))
# Out:
# --------------------------------------------------age-------------------------------------------------- -
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# Name: age, dtype: int64
# --------------------------------------------------sex-------------------------------------------------- -
# male      676
# female    662
# Name: sex, dtype: int64
# --------------------------------------------------bmi-------------------------------------------------- -
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
# 30.800     8
# 34.100     8
# 28.880     8
# 33.330     7
# 35.200     7
# Name: bmi, dtype: int64
# --------------------------------------------------children-------------------------------------------------- -
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
# ...

# %%
data.nunique()   #nunique() method returns the number of unique values for each column
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %%
data.describe().T # to check the Statistical summary
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %% [markdown]
# #### KEY OBSERVATION FROM ABOVE STATISTICAL SUMMARY -
# - All the columns has same count as 1338 which means there is no null values in the dataset.
# - The Mean is greater than the Median (50th percentile ) in all the columns except 'region', this shows that the data is right sided skewed specially in "Charges".
# - There is a large difference between the 75% (quantile 3) and max values in  "Charges" column,which indicates there is skewness in the data.
# - The std data in all columns are highly spreaded that means the possibility of outliers are more.
# - The 3 and 4 observations suggest that there are extreme outlier present in "Charges" columns .

# %% [markdown]
# ### DATA VISUALIZATION

# %%
 #ploting heatmap for Checking the null values 
plt.figure(figsize=(10,10))
plt.title('Heatmap of null values',fontsize=15)
sns.heatmap(data.isna())
# Out:
# <AxesSubplot:title={'center':'Heatmap of null values'}>

# %% [markdown]
# - No null value present.

# %% [markdown]
# ### Visualising Single Attributes -

# %%
# Analysis of age
sns.set()
plt.figure(figsize=(5,5))
sns.distplot(data['age'])
plt.title('Age Distribution')
plt.show()

# %%
# Analysis for sex
plt.figure(figsize=(5,5))
sns.countplot(x = 'sex', data = data)
plt.title('Sex Distribution')
plt.show()

# %%
# Analyis for BMI
sns.set()
plt.figure(figsize=(5,5))
sns.distplot(data['bmi'])
plt.title('BMI Distribution')
plt.show()

# %%
# Analysis for children
plt.figure(figsize=(5,5))
sns.countplot(x = 'children', data = data)
plt.title('children Distribution')
plt.show()

# %%
# Analysis of charge
plt.figure(figsize=(5,5))
sns.distplot(data['charges'])
plt.title('Charge Distribution')
plt.show()

# %%
data['region'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - The medical cost was seen highest in "Southeast" compared with the rest,where the data was almost similar.

# %%
data['smoker'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='smoker'>

# %% [markdown]
# - The overall count was seen highest in non-smokers(80%) than smokers.

# %% [markdown]
# #### Using various other methods to visualize the graphs and check the relationship between them and the Target Variable "Charges ".

# %%
#"Age" with "Charges "

plt.figure(figsize=(12,9))
plt.title('Age Vs Charge')
sns.barplot(x ='age',y ='charges',data = data , palette = 'husl')
plt.show()

# %% [markdown]
# - The general trend seems to be that 'medical charges' increase with age. However, there is significant variation at every age, and it's clear that age alone cannot be used to accurately determine medical charges.
# - "Charges" increase as the "Age" Increases. hence ,this shows a positive relationship.

# %%
#"BMI" with "charges"

plt.figure(figsize=(10,5))
plt.title('BMI Vs Charge')
sns.scatterplot(x ='bmi',y ='charges',hue="smoker" , data = data ,palette = 'Reds')
plt.show()

# %% [markdown]
# - It appears that for non-smokers, an increase in BMI doesn't seem to be related to an increase in medical charges. However, medical charges seem to be significantly higher for smokers with a BMI greater than 30.

# %%
#"Smoker" with "charges" 

plt.figure(figsize=(10,5))
plt.title('Sex Vs Charge')
sns.barplot(x ='sex',y ='charges',hue= "smoker", data = data , palette = 'husl')
plt.show()

# %% [markdown]
# - The above representation of graph depicits that  pattern of both male and female with smoking habits.
# - This clearly shows that both male and female with smoking habits has more medical cost billed by health insurance as it seems to be more prevant among males than females with smoking habit.

# %% [markdown]
# #### Creating some more graphs to visualize how the "charges" column is related to other columns ("children", "sex", "region" and "smoker")

# %%
# visiualising Charges by children with smoker.
plt.figsize=(10, 6)
sns.barplot(x="children", y="charges", hue="smoker", data=data)
plt.ylabel("Charges")
plt.title("Charges by Children with Smoker")
plt.show()

# %%
plt.figsize=(10, 6)
sns.barplot(x="smoker", y="charges", hue="sex", data=data)
plt.ylabel("Charges")
plt.title("Charges by Sex with Smoker")
plt.show()

# %% [markdown]
# - The male and female gender with smoking habit was seen more prevalent as compared with non smokers.

# %%
plt.figsize=(8, 6)
sns.barplot(x="region", y="charges", hue="smoker", data=data)
plt.ylabel("Charges")
plt.title("Charges by Region with Smoker")
plt.show()

# %% [markdown]
# - So overall,by analysing the highest medical insurance charges are in the 'Southeast' and the lowest are in the 'Southwest'.

# %%
f, axs = plt.subplots(1,1, figsize=(10,5))
sns.barplot(x='region', y='charges', hue='sex', data=data, palette='BuGn')
plt.show()

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 5))
sns.barplot(x='region', y='charges', hue='children', data=data, palette='Reds')
plt.show()

# %% [markdown]
# - From the above graphs, we can say that the highest charges are still in 'Southeast'. People in Southeast smoke more than people in 'Northeast' and 'Southwest'. And people with more than 2 or 3 childrens tend to have higher medical costs overall as well.

# %%
sns.lmplot(x = 'children', y = 'charges', data = data, hue='smoker', palette='Set1', scatter_kws={"s": 10})

# %% [markdown]
# - Smoking has the highest impact on the medical insurance costs, even though costs are increasing with age, bmi and children. Also people with children tend to smoke less.

# %% [markdown]
# ### Converting Categorical Features to Numerical Features

# %%
clean_data  = {'sex':{'male': 0 ,'female': 1},
               'smoker':{'no':0,'yes':1},
              'region':{'northwest':0, 'northeast':1,'southeast':2,'southwest':3}}


data_copy = data.copy()
data_copy.replace(clean_data, inplace=True)

# %%
data_copy
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       1       3  16884.92400
# 1      18    0  33.770         1       0       2   1725.55230
# 2      28    0  33.000         3       0       2   4449.46200
# 3      33    0  22.705         0       0       0  21984.47061
# 4      32    0  28.880         0       0       0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    0  30.970         3       0       0  10600.54830
# 1334   18    1  31.920         0       0       1   2205.98080
# 1335   18    1  36.850         0       0       2   1629.83350
# 1336   21    1  25.800         0       0       3   2007.94500
# 1337   61    1  29.070         0       1       0  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### CORRELATION MATRIX

# %%
datacor = data_copy.corr()  # to check the correlation of the dataset.
datacor
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000  0.020856  0.109272  0.042469 -0.025019  0.003243  0.299008
# sex       0.020856  1.000000 -0.046371 -0.017163 -0.076185 -0.007974 -0.057292
# bmi       0.109272 -0.046371  1.000000  0.012759  0.003750  0.156686  0.198341
# children  0.042469 -0.017163  0.012759  1.000000  0.007673 -0.001907  0.067998
# smoker   -0.025019 -0.076185  0.003750  0.007673  1.000000  0.013246  0.787251
# region    0.003243 -0.007974  0.156686 -0.001907  0.013246  1.000000  0.011741
# charges   0.299008 -0.057292  0.198341  0.067998  0.787251  0.011741  1.000000

# %%
#constructing a heatmap to understand the correlation between the columns .

plt.figure(figsize=(10,10))
sns.heatmap(datacor, cmap="YlGnBu" , annot = True ,fmt = ".2f")
plt.title("Dependencies of Medical Charges")
plt.show()

# %% [markdown]
# #### Key Observations -
# - Darker shades are highly correlated to each other.
# - 'Smoker','age' and 'BMI' are positively correlated to each other.
# - These are the most important factors that determines "Charges"(target variable).
# - "Sex","Children" and "religion" donot affect the target variable "Charges " as these have less correlation with each other , so we can drop them if required .

# %%
plt.figure(figsize=(22,7))
data.corr()['charges'].sort_values(ascending=False).plot(kind='bar',color='c')
plt.xlabel('Column with target name',fontsize=14)
plt.ylabel("values",fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %% [markdown]
# - Correlation was seen highest in "Charges" while the least among "Children".

# %%
data_copy.charges.corr(data_copy.age)
# Out:
# 0.29900819333064765

# %%
data_copy.charges.corr(data_copy.bmi)
# Out:
# 0.19834096883362892

# %%
data_copy.charges.corr(data_copy.smoker)
# Out:
# 0.7872514304984772

# %% [markdown]
# #### Checking Outliers

# %%
# checking outliers using boxplot of clean data .

plt.figure(figsize=(15,15),facecolor='white')
numbr = 1

for col in data_copy:
    if numbr <= 7:
        ax = plt.subplot(4,3,numbr)
        sns.boxplot(data_copy[col])
        plt.xlabel(col,fontsize=16)
    numbr+= 1
plt.show()

# %%
# Removing outlier using Z-Score method

from scipy.stats import zscore

# %%
z=np.abs(zscore(data_copy))
z
# abs(absolute function) will make all the negative data as a positive data.
# Out:
#            age       sex       bmi  children    smoker    region   charges
# 0     1.438764  1.010519  0.453320  0.908614  1.970587  1.343746  0.298584
# 1     1.509965  0.989591  0.509621  0.078767  0.507463  0.438898  0.953689
# 2     0.797954  0.989591  0.383307  1.580926  0.507463  0.438898  0.728675
# 3     0.441948  0.989591  1.305531  0.908614  0.507463  1.370796  0.719843
# 4     0.513149  0.989591  0.292556  0.908614  0.507463  1.370796  0.776802
# ...        ...       ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.580926  0.507463  1.370796  0.220551
# 1334  1.509965  1.010519  0.206139  0.908614  0.507463  0.465949  0.914002
# 1335  1.509965  1.010519  1.014878  0.908614  0.507463  0.438898  0.961596
# 1336  1.296362  1.010519  0.797813  0.908614  0.507463  1.343746  0.930362
# 1337  1.551686  1.010519  0.261388  0.908614  1.970587  1.370796  1.311053
#
# [1338 rows x 7 columns]

# %%
# clean data without outliers

meddata=data_copy[(z<3).all(axis=1)]   
meddata
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       1       3  16884.92400
# 1      18    0  33.770         1       0       2   1725.55230
# 2      28    0  33.000         3       0       2   4449.46200
# 3      33    0  22.705         0       0       0  21984.47061
# 4      32    0  28.880         0       0       0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    0  30.970         3       0       0  10600.54830
# 1334   18    1  31.920         0       0       1   2205.98080
# 1335   18    1  36.850         0       0       2   1629.83350
# 1336   21    1  25.800         0       0       3   2007.94500
# 1337   61    1  29.070         0       1       0  29141.36030
#
# [1309 rows x 7 columns]

# %%
print('percentage of loss of data by zscore is :',(data_copy.shape[0]-meddata.shape[0])/data_copy.shape[0])
# Out:
# percentage of loss of data by zscore is : 0.021674140508221227

# %%
# Rechecking outliers using boxplot of clean data .

plt.figure(figsize=(15,15),facecolor='white')
numb = 1

for col in meddata:
    if numb <= 7:
        ax = plt.subplot(4,3,numb)
        sns.boxplot(meddata[col])
        plt.xlabel(col,fontsize=16)
    numb+= 1
plt.show()

# %%
data_copy.shape
# Out:
# (1338, 7)

# %%
meddata.shape
# Out:
# (1309, 7)

# %% [markdown]
# #### Removing the Outliers by IQR method

# %%
Q1=data_copy.quantile(0.25)
Q3=data_copy.quantile(0.75)

IQR=Q3-Q1

df=data_copy[~((data_copy <(Q1-1.5*IQR))|(data_copy>(Q3+1.5*IQR))).any(axis=1)]

print('percentage of loss of data by IQR is :',(data_copy.shape[0]-df.shape[0])/data_copy.shape[0])
# Out:
# percentage of loss of data by IQR is : 0.21150971599402094

# %% [markdown]
# #### TO CHECK THE DISTRIBUTION OF SKEWNESS

# %%
# to check the distribution of skewness.

plt.figure(figsize=(15,20),facecolor ='white')
num = 1 

for i in meddata:
    if num <= 7:
        ax=plt.subplot(4,3,num)
        sns.histplot(meddata[i], kde=True, bins=20 )
        plt.xlabel(i, fontsize = 18)
    num += 1
    
plt.show()

# %% [markdown]
# #### Checking for skewness  and Kurtosis

# %%
meddata.skew()
# Out:
# age         0.051340
# sex         0.010708
# bmi         0.191432
# children    0.738119
# smoker      1.482731
# region     -0.022504
# charges     1.437160
# dtype: float64

# %%
print("SKEWNESS AND KURTOSIS FOR ALL COLUMNS ")
print("_______________________________________________________________")

for col in meddata.columns:
    print('{0} : Skewness{1: .2f} and kurtosis {2: .2f}'. format(col,meddata[col].skew(),meddata[col].kurt()))
# Out:
# SKEWNESS AND KURTOSIS FOR ALL COLUMNS
# _______________________________________________________________
# age : Skewness 0.05 and kurtosis -1.25
# sex : Skewness 0.01 and kurtosis -2.00
# bmi : Skewness 0.19 and kurtosis -0.30
# children : Skewness 0.74 and kurtosis -0.58
# smoker : Skewness 1.48 and kurtosis  0.20
# region : Skewness-0.02 and kurtosis -1.33
# charges : Skewness 1.44 and kurtosis  1.21

# %%
meddata['charges']= np.cbrt(meddata['charges'])

# %%
meddata.skew()
# Out:
# age         0.051340
# sex         0.010708
# bmi         0.191432
# children    0.738119
# smoker      1.482731
# region     -0.022504
# charges     0.481700
# dtype: float64

# %% [markdown]
# #### key observation-
# - Using cuberoot , skewness of "charges " has been reduced.
# - As we observe that our data is continious type ,so we have to use regression techniques in our model.

# %%
# Visualising how the data has been distributed after removing skewness from " charges"

plt.figure(figsize=(10,7))
sns.distplot(meddata['charges'])
plt.title('Plot for charges')
plt.xlabel('charges')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# - This graph looks almost normal and skewness is reduced in "Charges" column.

# %%
sns.pairplot(meddata,hue ="charges")

# %% [markdown]
#  - The pairplot gives the pairwise relation between  the features.

# %% [markdown]
# #### SPLITING THE DATA WITH TARGET AND FEATURES VALUES

# %%
x=meddata.iloc[:,0:-1]
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       1       3
# 1      18    0  33.770         1       0       2
# 2      28    0  33.000         3       0       2
# 3      33    0  22.705         0       0       0
# 4      32    0  28.880         0       0       0
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       0       0
# 1334   18    1  31.920         0       0       1
# 1335   18    1  36.850         0       0       2
# 1336   21    1  25.800         0       0       3
# 1337   61    1  29.070         0       1       0
#
# [1309 rows x 6 columns]

# %%
y=meddata.iloc[:,-1]
y
# Out:
# 0       25.654666
# 1       11.994331
# 2       16.447599
# 3       28.013799
# 4       15.695891
#           ...
# 1333    21.967271
# 1334    13.017690
# 1335    11.768318
# 1336    12.615872
# 1337    30.773007
# Name: charges, Length: 1309, dtype: float64

# %%
print('x shape:',x.shape)
print('y shape :',y.shape)
# Out:
# x shape: (1309, 6)
# y shape : (1309,)

# %% [markdown]
# #### FEATURE SCALING-

# %%
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
scaler= StandardScaler()
x= pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            age       sex       bmi  children    smoker    region
# 0    -1.439063  1.005362 -0.449359 -0.929616  1.984848  1.352435
# 1    -1.510086 -0.994667  0.533391 -0.040093 -0.503817  0.448279
# 2    -0.799859 -0.994667  0.404478  1.738954 -0.503817  0.448279
# 3    -0.444746 -0.994667 -1.319101 -0.929616 -0.503817 -1.360033
# 4    -0.515769 -0.994667 -0.285288 -0.929616 -0.503817 -1.360033
# ...        ...       ...       ...       ...       ...       ...
# 1304  0.762639 -0.994667  0.064617  1.738954 -0.503817 -1.360033
# 1305 -1.510086  1.005362  0.223666 -0.929616 -0.503817 -0.455877
# 1306 -1.510086  1.005362  1.049041 -0.929616 -0.503817  0.448279
# 1307 -1.297018  1.005362 -0.800939 -0.929616 -0.503817  1.352435
# 1308  1.543888  1.005362 -0.253479 -0.929616  1.984848 -1.360033
#
# [1309 rows x 6 columns]

# %% [markdown]
# - By doing Feature Scaling , we have scaled the data using standard scaler to overcome the issues of biasness.

# %% [markdown]
# ### MODEL BUILDING-

# %%
# Models:
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor

# for cross validation
from sklearn.model_selection import cross_val_score,RandomizedSearchCV,GridSearchCV

# Matrics for Evaluation
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,accuracy_score,confusion_matrix

# %%
#split data, using train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print('Size of X_train : ', x_train.shape)
print('Size of y_train : ', y_train.shape)
print('Size of X_test : ', x_test.shape)
print('Size of Y_test : ', y_test.shape)
# Out:
# Size of X_train :  (1047, 6)
# Size of y_train :  (1047,)
# Size of X_test :  (262, 6)
# Size of Y_test :  (262,)

# %% [markdown]
# #### Checking the mean value as a predictor  using dummy regressor.

# %%
y_train.mean()
# Out:
# 21.628968448076115

# %%
dumb_reg = DummyRegressor(strategy='mean')
dumb_reg.fit(x_train, y_train)
dumb_reg.constant_
# Out:
# array([[21.62896845]])

# %% [markdown]
# - By using dummy regressor verifying the above mean.Both looks almost same

# %% [markdown]
# ### 1) Linear Regression

# %%
# Training method

lm = LinearRegression()
lm.fit(x_train,y_train)
lm.score(x_train,y_train)
# Out:
# 0.7666253652390969

# %%
lm.coef_
# Out:
# array([ 2.97022892,  0.16879013,  0.67526758,  0.63456015,  4.80074745,
#        -0.26156347])

# %%
lm.intercept_
# Out:
# 21.69492953088794

# %%
#testing method

pred_train=lm.predict(x_train)
print(r2_score(y_train,pred_train))

pred_test=lm.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.7666253652390969
# 0.8174492012844577

# %%
cv_linearreg = cross_val_score(estimator = lm, X = x, y = y, cv = 5)

y_pred_linearreg_train = lm.predict(x_train)
r2_score_linearreg_train = r2_score(y_train, y_pred_linearreg_train)

y_pred_linearreg_test = lm.predict(x_test)
r2_score_linearreg_test = r2_score(y_test, y_pred_linearreg_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_pred_linearreg_test)))

print('CV Linear Regression : {0:.3f}'.format(cv_linearreg.mean()))
print('R2_score (train) : {0:.3f}'.format(r2_score_linearreg_train))
print('R2_score (test) : {0:.3f}'.format(r2_score_linearreg_test))
print('RMSE : {0:.3f}'.format(rmse))
print('Mean absolute error :',mean_absolute_error(y_test,y_pred_linearreg_test))
print('Mean squared error :',mean_squared_error(y_test,y_pred_linearreg_test))
# Out:
# CV Linear Regression : 0.774
# R2_score (train) : 0.767
# R2_score (test) : 0.817
# RMSE : 2.792
# Mean absolute error : 1.8879773551063346
# Mean squared error : 7.795426226464011

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')

plt.xlabel('Actual Charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)

plt.show()

# %% [markdown]
# ### 2) Support Vector Machine (Regression)

# %%
svr=SVR()
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
ypred=svr.predict(x_test)
ypred
print('mean squared error :',np.sqrt(mean_squared_error(y_test,ypred)))
# Out:
# mean squared error : 2.370736063990215

# %%
kernellist = ['linear','poly','rbf']

for i in kernellist:
    svr = SVR(kernel = i)
    svr.fit(x_train,y_train)
    
    print ("SCORE OF:",i,"=",svr.score(x_train,y_train))
    
    svr.predict(x_test)
    print('mean squared error of :',i,np.sqrt(mean_squared_error(y_test,ypred)))
    
rmse_svr=np.sqrt(mean_squared_error(y_test,ypred))
rmse_svr
# Out:
# SCORE OF: linear = 0.735033911569872
# mean squared error of : linear 2.370736063990215
# SCORE OF: poly = 0.798872785546129
# mean squared error of : poly 2.370736063990215
# SCORE OF: rbf = 0.8028597688004409
# mean squared error of : rbf 2.370736063990215
# 2.370736063990215

# %%
svrscore=cross_val_score(svr,x,y,cv=5)
sv=svrscore.mean()
print('Cross Val Score:',sv*100)
# Out:
# Cross Val Score: 81.02348158387312

# %% [markdown]
# ### Regularization

# %% [markdown]
# #### 3) Lasso Regularization

# %%
ls=Lasso()
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],
    'random_state':list(range(0,10))}

re=GridSearchCV(ls,parameters)
re.fit(x_train,y_train)
print(re.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
#final model training
ls=Lasso(alpha=0.001,random_state=0)
ls.fit(x_train,y_train)
ls_score = ls.score(x_train,y_train)
print(ls.score(x_train,y_train)*100)
# Out:
# 76.66252202821163

# %%
predlasso=ls.predict(x_test)
print(mean_squared_error(y_test,predlasso))
rmse_lasso=np.sqrt(mean_squared_error(y_test,predlasso))
print('RMSE:',np.sqrt(mean_squared_error(y_test,predlasso)))
# Out:
# 7.795953982549595
# Mean squared error: 2.792123561476031

# %%
lss=r2_score(y_test,predlasso)
lss*100
# Out:
# 81.74368424612001

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 77.38537243382655

# %%
ls.coef_
# Out:
# array([ 2.9694508 ,  0.16764689,  0.67418013,  0.63367889,  4.79960506,
#        -0.2604147 ])

# %% [markdown]
# #### 4) Ridge Regularization

# %%
rd = Ridge(alpha=.0001, random_state=42)
rd.fit(x_train, y_train)
print(rd.score(x_train,y_train))

cv_ridge = cross_val_score(estimator = rd, X = x, y = y, cv = 5)


y_pred_ridge_train = rd.predict(x_train)
r2_score_ridge_train = r2_score(y_train, y_pred_ridge_train)

y_pred_ridge_test = rd.predict(x_test)
r2_score_ridge_test = r2_score(y_test, y_pred_ridge_test)

rmse_ridge = (np.sqrt(mean_squared_error(y_test, y_pred_ridge_test)))
print('CV : {0:.3f}'.format(cv_ridge.mean()))
print('R2 score (train) : {0:.3f}'.format(r2_score_ridge_train))
print('R2 score (test) : {0:.3f}'.format(r2_score_ridge_test))
print('RMSE : {0:.3f}'.format(rmse_ridge))
# Out:
# 0.7666253652390898
# CV : 0.774
# R2 score (train) : 0.767
# R2 score (test) : 0.817
# RMSE : 2.792

# %% [markdown]
# #### 5)RandomForest Regressor

# %%
parameters = {
    'criterion':['mse','mae'],
    'max_features':['auto','sqrt','log2']
}

rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)

# %%
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion="mae",max_features="sqrt")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print('R2_score:',rfs*100)

rmse_rf = np.sqrt(mean_squared_error(y_test,pred_decision))

rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2_score: 86.78963139312582
# Cross Val Score: 81.86889045563905

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_decision,color='r')
plt.plot(y_test,y_test,color='b')

plt.xlabel('Actual Charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Random Forest Regressor',fontsize=18)

plt.show()

# %% [markdown]
# #### Visualizising All the algorithms together

# %%
models = [('Linear Regression', rmse, r2_score_linearreg_train, r2_score_linearreg_test, cv_linearreg.mean()),
          ('Ridge Regression', rmse_ridge, r2_score_ridge_train, r2_score_ridge_test, cv_ridge.mean()),
          ('Lasso Regression',rmse_lasso,predlasso,lss,cv_mean),
          ('Support Vector Regression', rmse_svr, y_test, ypred, sv),
          ('Random Forest Regression', rmse_rf, rfs,pred_decision, rfc)   
         ]

# %%
predict = pd.DataFrame(data = models, columns=['Model', 'RMSE', 'R2_Score(training)', 'R2_Score(test)', 'Cross-Validation'])
predict
# Out:
#                        Model      RMSE  \
# 0          Linear Regression  2.792029
# 1           Ridge Regression  2.792029
# 2           Lasso Regression  2.792124
# 3  Support Vector Regression  2.370736
# 4   Random Forest Regression  2.375120
#
#                                   R2_Score(training)  \
# 0                                           0.766625
# 1                                           0.766625
# 2  [23.54791020890197, 22.559951407980122, 27.133...
# 3  1172    22.302718
# 1069    22.191746
# 1001    32...
# 4                                           0.867896
#
#                                       R2_Score(test)  Cross-Validation
# 0                                           0.817449          0.773852
# 1                                           0.817449          0.773852
# 2                                           0.817437          0.773854
# 3  [22.491495855433875, 22.325070042283407, 30.02...          0.810235
# ...

# %%
plt.figure(figsize=(12,7))
predict.sort_values(by=['Cross-Validation'], ascending=False, inplace=True)

sns.barplot(x='Cross-Validation', y='Model',data = predict, palette='Reds')
plt.xlabel('Cross Validation Score')
plt.ylabel('Model')
plt.show()

# %% [markdown]
# #### SAVING THE MODEL-

# %%
import joblib
joblib.dump(rfs,'Medical_Cost_insurance.obj')
# Out:
# ['Medical_Cost_insurance.obj']

# %% [markdown]
# #### Conclusion-

# %% [markdown]
# - Random Forest Regression turned out to be the best model

# %% [markdown]
# ### **********Completed************
